# %% [markdown]
# <a href="https://colab.research.google.com/github/ayaz-ali-36/ai-identification-system/blob/main/Notebooks/day3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6501867e-9e2d-4912-8d46-30b2c2190438" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6501867e-9e2d-4912-8d46-30b2c2190438">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

image = cv2.imread(list(uploaded.keys())[0])


face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

print("Number of faces found:", len(faces))
print("Face location (x, y, width, height):", faces)
# Out:
# Number of faces found: 1
# Face location (x, y, width, height): [[ 68  36 110 110]]

# %%
image_copy = image.copy()

for (x, y, w, h) in faces:
    cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)
    print(f"Face at: x={x}, y={y}, width={w}, height={h}")

cv2_imshow(image_copy)
# Out:
# Face at: x=68, y=36, width=110, height=110
# <PIL.Image.Image image mode=RGB size=255x198>

# %%
for (x, y, w, h) in faces:
    face_crop = image[y:y+h, x:x+w]
    print("Cropped face shape:", face_crop.shape)
    cv2_imshow(face_crop)
# Out:
# Cropped face shape: (110, 110, 3)
# <PIL.Image.Image image mode=RGB size=110x110>
